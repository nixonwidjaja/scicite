# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import nltk
import torch 
import torch.nn as nn
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.utils import resample
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.optim import Adam
from transformers import AlbertTokenizer, AlbertForSequenceClassification

# %%
train_df = pd.read_json('train.jsonl', lines=True)
X_train = train_df['string']
y_train = train_df['label']

dev_df = pd.read_json('dev.jsonl', lines=True)
X_dev = dev_df['string']
y_dev = dev_df['label']

test_df = pd.read_json('test.jsonl', lines=True)
X_test = test_df['string']
y_test = test_df['label']

train_df
# Out:
#         source  citeEnd                                        sectionName  \
# 0     explicit    175.0                                       Introduction
# 1     explicit     36.0  Novel Quantitative Trait Loci for Seminal Root...
# 2     explicit    228.0                                       Introduction
# 3     explicit    110.0                                         Discussion
# 4     explicit    239.0                                         Discussion
# ...        ...      ...                                                ...
# 8238  explicit     50.0
# 8239  explicit    182.0                                         DISCUSSION
# 8240  explicit    120.0                                         DISCUSSION
# 8241  explicit    221.0
# 8242  explicit    102.0                                       Introduction
#
#       citeStart                                             string  \
# 0         168.0  However, how frataxin interacts with the Fe-S ...
# 1          16.0  In the study by Hickey et al. (2012), spikes w...
# 2         225.0  The drug also reduces catecholamine secretion,...
# 3          46.0  By clustering with lowly aggressive close kin ...
# 4         234.0  Ophthalmic symptoms are rare manifestations of...
# ...         ...                                                ...
# 8238       28.0  Importantly, the results of Pascalis et al. (2...
# 8239      179.0  As suggested by Nguena et al, there is a need ...
# 8240      108.0  Skeletal muscle is also a primary site of dise...
# 8241      185.0  ACTIVATION OF TRANSCRIPTION FACTORS Roles for ...
# 8242       82.0  Most studies focused on the relation between b...
#
#            label  label_confidence                             citingPaperId  \
# 0     background            1.0000  1872080baa7d30ec8fb87be9a65358cd3a7fb649
# 1     background            1.0000  ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b
# 2     background            1.0000  9cdf605beb1aa1078f235c4332b3024daa8b31dc
# 3     background            1.0000  d9f3207db0c79a3b154f3875c9760cc6b056904b
# 4     background            1.0000  88b86556857f4374842d2af2e359576806239175
# ...          ...               ...                                       ...
# 8238  background            0.7350  6f68ccd37718366c40ae6aeedf0b935bf560b215
# 8239  background            0.7508  f2a1c1704f9587c94ed95bc98179dc499e933f5e
# 8240  background            1.0000  18c97ea2ff60c110cc2a523e0fdf729608cbb083
# 8241      method               NaN  4ec9b89857c0b27e8a4bd3745b7358f387773527
# 8242  background            1.0000  42c954cad0de68657d4429b512d8fe75dceef13c
#
#                                   citedPaperId  isKeyCitation  \
# 0     894be9b4ea46a5c422e81ef3c241072d4c73fdc0           True
# 1     b6642e19efb8db5623b3cc4eef1c5822a6151107           True
# 2     4e6a17fb8d7a3cada601d942e22eb5da6d01adbd          False
# 3     2cc6ff899bf17666ad35893524a4d61624555ed7          False
# 4     a5bb0ff1a026944d2a47a155462959af2b8505a8          False
# ...                                        ...            ...
# 8238  60ed4bdabf92b2fbd6162dbd8979888cccca55d7           True
# 8239  574e659da7f6c62c07bfaaacd1f31d65bd75524c           True
# 8240  fc13b9c3dfcc121013edaa12fa8ce7842aaed21a          False
# 8241  81affdba19e38e2b17cf7b9e93792cc2028cf21d           True
# 8242  00afbfb391f7c15a73a4257b2c0fcd9767ece6a8           True
#
#                                                      id  \
# 0     1872080baa7d30ec8fb87be9a65358cd3a7fb649>894be...
# 1     ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b>b6642...
# 2     9cdf605beb1aa1078f235c4332b3024daa8b31dc>4e6a1...
# 3     d9f3207db0c79a3b154f3875c9760cc6b056904b>2cc6f...
# 4     88b86556857f4374842d2af2e359576806239175>a5bb0...
# ...                                                 ...
# 8238  6f68ccd37718366c40ae6aeedf0b935bf560b215>60ed4...
# 8239  f2a1c1704f9587c94ed95bc98179dc499e933f5e>574e6...
# 8240  18c97ea2ff60c110cc2a523e0fdf729608cbb083>fc13b...
# 8241  4ec9b89857c0b27e8a4bd3745b7358f387773527>81aff...
# 8242  42c954cad0de68657d4429b512d8fe75dceef13c>00afb...
#
#                                               unique_id  excerpt_index label2  \
# 0     1872080baa7d30ec8fb87be9a65358cd3a7fb649>894be...             11    NaN
# 1     ce1d09a4a3a8d7fd3405b9328f65f00c952cf64b>b6642...              2    NaN
# 2     9cdf605beb1aa1078f235c4332b3024daa8b31dc>4e6a1...              0    NaN
# 3     d9f3207db0c79a3b154f3875c9760cc6b056904b>2cc6f...              3    NaN
# 4     88b86556857f4374842d2af2e359576806239175>a5bb0...              2    NaN
# ...                                                 ...            ...    ...
# 8238  6f68ccd37718366c40ae6aeedf0b935bf560b215>60ed4...             15    NaN
# 8239  f2a1c1704f9587c94ed95bc98179dc499e933f5e>574e6...              1    NaN
# 8240  18c97ea2ff60c110cc2a523e0fdf729608cbb083>fc13b...              8    NaN
# 8241  4ec9b89857c0b27e8a4bd3745b7358f387773527>81aff...              0    NaN
# 8242  42c954cad0de68657d4429b512d8fe75dceef13c>00afb...              0    NaN
#
#       label2_confidence
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 8238                NaN
# 8239                NaN
# 8240                NaN
# 8241                NaN
# 8242                NaN
#
# [8243 rows x 15 columns]

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and transform string column
y_train = label_encoder.fit_transform(y_train)
y_dev = label_encoder.transform(y_dev)
y_test = label_encoder.transform(y_test)

print(y_train)
# Out:
# [0 0 0 ... 0 1 0]

# %%
def cleaning(text):
    stop_words = stopwords.words('english')
    text = text.lower()
    text = ' '.join(x for x in text.split() if x not in stop_words)
    return text

# %%
def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    words = []
    for x in text.split():
        x = lemmatizer.lemmatize(x)
        words.append(x)
    text = ' '.join(words)
    return text

# %%
def preprocessing(text):
    # Tokenization
    tokenizer = RegexpTokenizer(r'[a-zA-Z0-9]+')
    text = cleaning(text)
    text = lemmatize(text)
    text = ' '.join(tokenizer.tokenize(text))
    return text

# %%
def augment_data_multiclass(X, y):
    df = pd.concat([X, y], axis=1)
    majority_class_size = df['label'].value_counts().max()
    upsampled_dataframes = []
    for class_label in df['label'].unique():
        class_df = df[df['label'] == class_label]
        if len(class_df) < majority_class_size:
            class_df_upsampled = resample(class_df, replace=True, n_samples=majority_class_size, random_state=10)
            upsampled_dataframes.append(class_df_upsampled)
        else:
            upsampled_dataframes.append(class_df)
    upsampled_df = pd.concat(upsampled_dataframes)
    return upsampled_df['string'], upsampled_df['label']

# %%
model_name = 'albert-base-v2'
tokenizer = AlbertTokenizer.from_pretrained(model_name)
model = AlbertForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Encode the training data
encoded_data_train = tokenizer.batch_encode_plus(
    X_train,
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=512, 
    return_tensors='pt'
)

labels_train = torch.tensor(y_train)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /Users/farrelsalim/Library/Python/3.9/lib/python/site-packages/transformers/tokenization_utils_base.py:2688: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
# Create data loader for training
batch_size = 256

# Create DataLoader for training data
dataset_train = TensorDataset(encoded_data_train['input_ids'], encoded_data_train['attention_mask'], labels_train)
dataloader_train = DataLoader(dataset_train, sampler=RandomSampler(dataset_train), batch_size=batch_size)

# %%
# Freeze the non-last layer
for param in model.parameters():
    param.requires_grad = False
for param in model.classifier.parameters():
    param.requires_grad = True

# Define optimizer and loss function for training data
optimizer = Adam(model.parameters(), lr=1e-5, eps=1e-8)

epochs = 10

# Training loop
for _ in range(epochs):
    model.train()

    for train_batch in dataloader_train:
        optimizer.zero_grad()

        id, mask, label = train_batch
        outputs = model(id, attention_mask=mask, labels=label)

        loss = outputs.loss
        loss.backward()
        
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 20
#      17 optimizer.zero_grad()
#      19 id, mask, label = train_batch
# ---> 20 outputs = model(id, attention_mask=mask, labels=label)
#      22 loss = outputs.loss
#      23 loss.backward()
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/albert/modeling_albert.py:1067, in AlbertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1059 r"""
#    1060 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1061     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1062     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1063     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1064 """
#    1065 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1067 outputs = self.albert(
#    1068     input_ids=input_ids,
#    1069     attention_mask=attention_mask,
#    1070     token_type_ids=token_type_ids,
#    1071     position_ids=position_ids,
#    1072     head_mask=head_mask,
#    1073     inputs_embeds=inputs_embeds,
#    1074     output_attentions=output_attentions,
#    1075     output_hidden_states=output_hidden_states,
#    1076     return_dict=return_dict,
#    1077 )
#    1079 pooled_output = outputs[1]
#    1081 pooled_output = self.dropout(pooled_output)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/albert/modeling_albert.py:732, in AlbertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     727 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     729 embedding_output = self.embeddings(
#     730     input_ids, position_ids=position_ids, token_type_ids=token_type_ids, inputs_embeds=inputs_embeds
#     731 )
# --> 732 encoder_outputs = self.encoder(
#     733     embedding_output,
#     734     extended_attention_mask,
#     735     head_mask=head_mask,
#     736     output_attentions=output_attentions,
#     737     output_hidden_states=output_hidden_states,
#     738     return_dict=return_dict,
#     739 )
#     741 sequence_output = encoder_outputs[0]
#     743 pooled_output = self.pooler_activation(self.pooler(sequence_output[:, 0])) if self.pooler is not None else None
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/albert/modeling_albert.py:481, in AlbertTransformer.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     478 # Index of the hidden group
#     479 group_idx = int(i / (self.config.num_hidden_layers / self.config.num_hidden_groups))
# --> 481 layer_group_output = self.albert_layer_groups[group_idx](
#     482     hidden_states,
#     483     attention_mask,
#     484     head_mask[group_idx * layers_per_group : (group_idx + 1) * layers_per_group],
#     485     output_attentions,
#     486     output_hidden_states,
#     487 )
#     488 hidden_states = layer_group_output[0]
#     490 if output_attentions:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/albert/modeling_albert.py:433, in AlbertLayerGroup.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states)
#     430 layer_attentions = ()
#     432 for layer_index, albert_layer in enumerate(self.albert_layers):
# --> 433     layer_output = albert_layer(hidden_states, attention_mask, head_mask[layer_index], output_attentions)
#     434     hidden_states = layer_output[0]
#     436     if output_attentions:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/albert/modeling_albert.py:398, in AlbertLayer.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states)
#     388 def forward(
#     389     self,
#     390     hidden_states: torch.Tensor,
#    (...)
#     394     output_hidden_states: bool = False,
#     395 ) -> Tuple[torch.Tensor, torch.Tensor]:
#     396     attention_output = self.attention(hidden_states, attention_mask, head_mask, output_attentions)
# --> 398     ffn_output = apply_chunking_to_forward(
#     399         self.ff_chunk,
#     400         self.chunk_size_feed_forward,
#     401         self.seq_len_dim,
#     402         attention_output[0],
#     403     )
#     404     hidden_states = self.full_layer_layer_norm(ffn_output + attention_output[0])
#     406     return (hidden_states,) + attention_output[1:]
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pytorch_utils.py:237, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     234     # concatenate output at same dimension
#     235     return torch.cat(output_chunks, dim=chunk_dim)
# --> 237 return forward_fn(*input_tensors)
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/albert/modeling_albert.py:411, in AlbertLayer.ff_chunk(self, attention_output)
#     409 ffn_output = self.ffn(attention_output)
#     410 ffn_output = self.activation(ffn_output)
# --> 411 ffn_output = self.ffn_output(ffn_output)
#     412 return ffn_output
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Encode test data
encoded_data_test = tokenizer.batch_encode_plus(
    X_test,
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=512, 
    return_tensors='pt'
)
labels_test = torch.tensor(y_test)

# Create data loader for test data
test_dataset = TensorDataset(encoded_data_test['input_ids'], encoded_data_test['attention_mask'], labels_test)
test_dataloader = DataLoader(test_dataset, sampler=SequentialSampler(test_dataset), batch_size=batch_size)
# Out:
# /Users/farrelsalim/Library/Python/3.9/lib/python/site-packages/transformers/tokenization_utils_base.py:2688: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
#Evaluate with test data

model.eval()
test_loss = 0
num_test_batches = 0

for test_batch in test_dataloader:
    id, mask, label = test_batch

    with torch.no_grad():
        outputs = model(id, attention_mask=mask, labels=label)

    test_loss += outputs.loss.item()
    num_test_batches += 1

avg_val_loss = test_loss / num_test_batches

print(avg_val_loss)
# Out:
# 1.233811616897583
